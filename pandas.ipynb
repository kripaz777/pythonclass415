# %%
try:
    file = open('data.csv','x')
    file.close()
except:
    print("The file is already there.")
# Out:
# The file is already there.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\aayush\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\aayush\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\aayush\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aayush\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\aayush\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    sn    name  age        add       phone
# 0   1     Ram   23  Kathmandu  9808667876
# 1   2   Shyam   67  Bhaktapur  9808667654
# 2   3    Hari   34   lalitpur  9808664532
# 3   4   Nabin   45       Bara  9808667654
# 4   5  Nabina   23    Chitwan  9806778765
# 5   6    SIta   45  Kathmandu  9867778765

# %%
df = pd.read_csv('data.csv',nrows = 5)
df
# Out:
#    sn    name  age        add       phone
# 0   1     Ram   23  Kathmandu  9808667876
# 1   2   Shyam   67  Bhaktapur  9808667654
# 2   3    Hari   34   lalitpur  9808664532
# 3   4   Nabin   45       Bara  9808667654
# 4   5  Nabina   23    Chitwan  9806778765

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df
# Out:
#       name  age        add       phone
# sn
# 1      Ram   23  Kathmandu  9808667876
# 2    Shyam   67  Bhaktapur  9808667654
# 3     Hari   34   lalitpur  9808664532
# 4    Nabin   45       Bara  9808667654
# 5   Nabina   23    Chitwan  9806778765
# 6     SIta   45  Kathmandu  9867778765

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df.head(3)
# Out:
#      name  age        add       phone
# sn
# 1     Ram   23  Kathmandu  9808667876
# 2   Shyam   67  Bhaktapur  9808667654
# 3    Hari   34   lalitpur  9808664532

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df.tail(3)
# Out:
#       name  age        add       phone
# sn
# 4    Nabin   45       Bara  9808667654
# 5   Nabina   23    Chitwan  9806778765
# 6     SIta   45  Kathmandu  9867778765

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df.iloc[1:4]
# Out:
#      name  age        add       phone
# sn
# 2   Shyam   67  Bhaktapur  9808667654
# 3    Hari   34   lalitpur  9808664532
# 4   Nabin   45       Bara  9808667654

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df.loc[2:5]
# Out:
#       name  age        add       phone
# sn
# 2    Shyam   67  Bhaktapur  9808667654
# 3     Hari   34   lalitpur  9808664532
# 4    Nabin   45       Bara  9808667654
# 5   Nabina   23    Chitwan  9806778765

# %%
df = pd.read_csv('data.csv',index_col = 'name')
df.loc['Shyam':'Nabina']
# Out:
#         sn  age        add       phone
# name
# Shyam    2   67  Bhaktapur  9808667654
# Hari     3   34   lalitpur  9808664532
# Nabin    4   45       Bara  9808667654
# Nabina   5   23    Chitwan  9806778765

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df['add']
# Out:
# sn
# 1    Kathmandu
# 2    Bhaktapur
# 3     lalitpur
# 4         Bara
# 5      Chitwan
# 6    Kathmandu
# Name: add, dtype: object

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df['add'] == 'Kathmandu'
# Out:
# sn
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: add, dtype: bool

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df[df['add'] == 'Kathmandu']
# Out:
#     name  age        add       phone
# sn
# 1    Ram   23  Kathmandu  9808667876
# 6   SIta   45  Kathmandu  9867778765

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df[df['age'] > 25]
# Out:
#      name  age        add       phone
# sn
# 2   Shyam   67  Bhaktapur  9808667654
# 3    Hari   34   lalitpur  9808664532
# 4   Nabin   45       Bara  9808667654
# 6    SIta   45  Kathmandu  9867778765

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df[(df['age'] > 25) & (df['add'] == 'Kathmandu')]
# Out:
#     name  age        add       phone
# sn
# 6   SIta   45  Kathmandu  9867778765

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
data = df[df['age'] > 25]
data.to_csv('new_data.csv')

# %%
# list inside dict
data = {'name':['Ram','Shyam','Hari','Sita','Gita'],
       'age':[23,45,67,89,43],
       'add':['Kathmandu','Bara','Jhapa','Bhaktapur','Lalitpur']}
data
# Out:
# {'name': ['Ram', 'Shyam', 'Hari', 'Sita', 'Gita'],
#  'age': [23, 45, 67, 89, 43],
#  'add': ['Kathmandu', 'Bara', 'Jhapa', 'Bhaktapur', 'Lalitpur']}

# %%
import pandas as pd
# list inside dict
data = {'name':['Ram','Shyam','Hari','Sita','Gita'],
       'age':[23,45,67,89,43],
       'add':['Kathmandu','Bara','Jhapa','Bhaktapur','Lalitpur']}
df = pd.DataFrame(data)
df.to_csv('new_data.csv')
df
# Out:
#     name  age        add
# 0    Ram   23  Kathmandu
# 1  Shyam   45       Bara
# 2   Hari   67      Jhapa
# 3   Sita   89  Bhaktapur
# 4   Gita   43   Lalitpur

# %%
file = open('new_data.csv','a')

file.write('\n5,Sameer,45,Kathmandu,9808667787')
file.close()

# %%
df = pd.read_csv('new_data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df = pd.read_csv('new_data.csv')
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 4 fields in line 8, saw 5

# %%
import csv
data = [['name','age','add'],
        ['Ram',45,'Kathmandu'],
       ['Shyam',34,'Bhaktapur'],
       ['Hari',34,'Lalitpur']]

file = open('list_data.csv','w')
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
df = pd.read_csv('list_data.csv')
df
# Out:
#     name  age        add
# 0    Ram   45  Kathmandu
# 1  Shyam   34  Bhaktapur
# 2   Hari   34   Lalitpur

# %%
import csv
data = []
with open('list_data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(row)
data
# Out:
# [{'name': 'Ram', 'age': '45', 'add': 'Kathmandu'},
#  {'name': 'Shyam', 'age': '34', 'add': 'Bhaktapur'},
#  {'name': 'Hari', 'age': '34', 'add': 'Lalitpur'}]

# %%
import csv
csv_columns = ['Name', 'Age', 'Address']
dict = [
{'Name':'Aayush','Age':23,'Address':'Katmandu'},
{'Name':'Shyam','Age':33,'Address':'Patan'}
]

with open("data.csv", 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    
    for data in dict:
        writer.writerow(data)

# %%
df1 = pd.DataFrame({'Names': ['Andreas', 'George', 'Steve','Sarah', 'Joanna', 'Hanna'],'Age':[21, 22, 20, 19, 18, 23]})

df2 = pd.DataFrame({'Names': ['Pete', 'Jordan', 'Gustaf','Sophie', 'Sally', 'Simone'],'Age':[22, 21, 19, 19, 29, 21]})

df3 = pd.DataFrame({'Names': ['Ulrich', 'Donald', 'Jon','Jessica', 'Elisabeth', 'Diana'],'Age':[21, 21, 20, 19, 19, 22]})

df = pd.concat([df1, df2, df3])

df.to_csv('boooks.csv')

# %%
import pandas as pd
df = pd.read_csv('boooks.csv',usecols = ['Names','Age'])
df
# Out:
#         Names  Age
# 0     Andreas   21
# 1      George   22
# 2       Steve   20
# 3       Sarah   19
# 4      Joanna   18
# 5       Hanna   23
# 6        Pete   22
# 7      Jordan   21
# 8      Gustaf   19
# 9      Sophie   19
# 10      Sally   29
# 11     Simone   21
# 12     Ulrich   21
# 13     Donald   21
# 14        Jon   20
# 15    Jessica   19
# 16  Elisabeth   19
# 17      Diana   22
